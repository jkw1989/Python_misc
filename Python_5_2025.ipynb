# %% [markdown]
# <a href="https://colab.research.google.com/github/jkw1989/Python_misc/blob/main/Python_5_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Variables

# %%
salary = 100000

# %%
base_salary = .5

# %%
salary*(1+base_salary)
# Out:
# 150000.0

# %%
job_count = 42
print(job_count)
# Out:
# 42

# %%
job_tite = "Data Engineer"
company = "DataWorks"
remote_statuS = True

# %%
print(job_tite, company, remote_statuS)
# Out:
# Data Engineer DataWorks True

# %%
base_salary = 72000
bonus = 20000

# %%
total_compensation = base_salary + bonus

# %%
total_compensation
# Out:
# 92000

# %%
monthy_salary = base_salary/12

# %%
print(monthy_salary)
# Out:
# 6000.0

# %%
print(total_compensation, job_tite)
# Out:
# 92000 Data Engineer

# %% [markdown]
# # Terms
#
# * Objects = instance of a class
# * Variables = Points to an objects
# * Function = Manipulator of objects

# %%
def display_info (title, location, salary):
  return (f"JOB: {title}\nLOCATION: {location}\nSALARY: ${salary}")

# %%
print(display_info("title","Seattle",12))
# Out:
# JOB: title
# LOCATION: Seattle
# SALARY: $12

# %%
class JobPost:
  def display_info (title, location, salary):
    return (f"JOB: {title}\nLOCATION: {location}\nSALARY: ${salary}")

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[['total_rooms', 'total_bedrooms']]
# Out:
#       total_rooms  total_bedrooms
# 0          3885.0           661.0
# 1          1510.0           310.0
# 2          3589.0           507.0
# 3            67.0            15.0
# 4          1241.0           244.0
# ...           ...             ...
# 2995       1450.0           642.0
# 2996       5257.0          1082.0
# 2997        956.0           201.0
# 2998         96.0            14.0
# 2999       1765.0           263.0
#
# [3000 rows x 2 columns]

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df = dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
display(df.tail(3))
# Out:
#           job_title_short                                          job_title  \
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location              job_via  \
# 785738                             Malaysia     melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 785740                                India       melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# ...

# %%
df.search_location
# Out:
# 0         Texas, United States
# 1                       Mexico
# 2                      Germany
# 3         Texas, United States
# 4                        Sudan
#                   ...
# 785736               Singapore
# 785737                 Germany
# 785738                Malaysia
# 785739                   Sudan
# 785740                   India
# Name: search_location, Length: 785741, dtype: object

# %%
df[['company_name','search_location']].head(3)
# Out:
#                  company_name       search_location
# 0        Boehringer Ingelheim  Texas, United States
# 1  Hewlett Packard Enterprise                Mexico
# 2    ALPHA Augmented Services               Germany

# %%
df[['company_name','job_location']].iloc[90:100]
# Out:
#                                company_name                job_location
# 90      Concurrent Technologies Corporation                   Australia
# 91                                 Talently               Temuco, Chile
# 92                             Apex Systems                    Anywhere
# 93  Get It Recruit - Information Technology                    Anywhere
# 94                                    Adobe                    Lehi, UT
# 95                  Crimson Interactive Inc  Mumbai, Maharashtra, India
# 96                          King's Hawaiian                Torrance, CA
# 97    Solihull Metropolitan Borough Council              United Kingdom
# 98                   MUFG Investor Services         Toronto, ON, Canada
# 99                                    Agoda                   Miami, FL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
unique = df.job_title.unique()

# %%
df[(df.job_title_short == "Data Analyst") & (df.job_country == "Sudan")]
# Out:
#        job_title_short                                          job_title  \
# 318       Data Analyst                            Compliance Data Analyst
# 503       Data Analyst                            Data Governance Analyst
# 2033      Data Analyst                                REMOTE Data Analyst
# 2210      Data Analyst                                       Data Analyst
# 2390      Data Analyst                                       Data Analyst
# ...                ...                                                ...
# 782689    Data Analyst                                       Data Analyst
# 782973    Data Analyst  Data Center Analyst Advisor - Full-time / Part...
# 784619    Data Analyst                                       Data Analyst
# 785122    Data Analyst                          Director, Data Governance
# 785633    Data Analyst        Data Analyst Senior - Full-time / Part-time
#
#              job_location          job_via job_schedule_type  \
# ...

# %%
df.iloc[3]
# Out:
# job_title_short                                              Data Engineer
# job_title                LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# job_location                                               San Antonio, TX
# job_via                                                  via Diversity.com
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                       Texas, United States
# job_posted_date                                        2023-07-04 13:01:41
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                  United States
# salary_rate                                                           None
# ...

# %%
df.job_country.unique()
# Out:
# array(['United States', 'Mexico', 'Germany', 'Sudan', 'Romania',
#        'Denmark', 'Switzerland', 'France', 'Brazil', 'United Kingdom',
#        'India', 'Poland', 'Belgium', 'Russia', 'Serbia', 'Singapore',
#        'Costa Rica', 'Ireland', 'Italy', 'Malaysia', 'Canada', 'Uruguay',
#        'Namibia', 'Estonia', 'Israel', 'Hungary', 'Austria',
#        'Philippines', 'Egypt', 'Australia', 'Chile', 'Spain',
#        'Netherlands', 'South Africa', 'Colombia', 'Hong Kong', 'Kuwait',
#        'Finland', 'Luxembourg', 'China', 'Puerto Rico', 'Sweden',
#        'Saudi Arabia', 'Argentina', 'Turkey', 'Panama', 'Nigeria',
#        'New Zealand', 'Ukraine', 'Jordan', 'United Arab Emirates',
#        'Armenia', 'Pakistan', 'Lesotho', 'Mauritius', 'Portugal',
#        'Bahrain', 'Taiwan', "Côte d'Ivoire", 'U.S. Virgin Islands',
#        'Réunion', 'Kazakhstan', 'Lithuania', 'Moldova', 'Belarus',
#        'Cyprus', 'Bulgaria', 'Honduras', 'Czechia', 'Peru', 'South Korea',
# ...

# %%
df['job_posted_date'] =  pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.sort_values("job_title")
# Out:
#              job_title_short  \
# 449749         Data Engineer
# 453421         Data Engineer
# 279631          Data Analyst
# 557033        Data Scientist
# 127878        Data Scientist
# ...                      ...
# 778368     Software Engineer
# 271129  Senior Data Engineer
# 595941         Data Engineer
# 138132         Data Engineer
# 784492         Data Engineer
#
#                                                 job_title  \
# 449749  !! Data Engineer [W2] | FULLY REMOTE | Immedia...
# 453421  !!urgent Hiring!! AWS Lead data engineer(Hybri...
# 279631        !URGENT HIRING! Data Analyst (hybrid setup)
# 557033       !เจ้าหน้าที่วิศวกรรมข้อมูล (MIS & Analytics)
# 127878       !เจ้าหน้าที่วิศวกรรมข้อมูล (MIS & Analytics)
# ...                                                   ...
# 778368                                     🧱 Project Lead
# 271129                             🧱 Senior Data Engineer
# 595941                 🩺 BI Data Engineer - Medtech - H/F
# ...

# %%
df.drop("job_title",axis=1)
# Out:
#              job_title_short                         job_location  \
# 0       Senior Data Engineer                        Watertown, CT
# 1               Data Analyst         Guadalajara, Jalisco, Mexico
# 2              Data Engineer                      Berlin, Germany
# 3              Data Engineer                      San Antonio, TX
# 4              Data Engineer                       Washington, DC
# ...                      ...                                  ...
# 785736     Software Engineer                            Singapura
# 785737          Data Analyst                   Bad Rodach, Jerman
# 785738      Business Analyst                             Malaysia
# 785739         Data Engineer  Newark, New Jersey, Amerika Serikat
# 785740     Software Engineer                                India
#
#                           job_via job_schedule_type  job_work_from_home  \
# 0                 via Work Nearby         Full-time               False
# ...
