# %% [markdown]
# <a href="https://colab.research.google.com/github/jkw1989/Python_misc/blob/main/Python_5_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Variables

# %%
salary = 100000

# %%
base_salary = .5

# %%
salary*(1+base_salary)
# Out:
# 150000.0

# %%
job_count = 42
print(job_count)
# Out:
# 42

# %%
job_tite = "Data Engineer"
company = "DataWorks"
remote_statuS = True

# %%
print(job_tite, company, remote_statuS)
# Out:
# Data Engineer DataWorks True

# %%
base_salary = 72000
bonus = 20000

# %%
total_compensation = base_salary + bonus

# %%
total_compensation
# Out:
# 92000

# %%
monthy_salary = base_salary/12

# %%
print(monthy_salary)
# Out:
# 6000.0

# %%
print(total_compensation, job_tite)
# Out:
# 92000 Data Engineer

# %% [markdown]
# # Terms
#
# * Objects = instance of a class
# * Variables = Points to an objects
# * Function = Manipulator of objects

# %%
def display_info (title, location, salary):
  return (f"JOB: {title}\nLOCATION: {location}\nSALARY: ${salary}")

# %%
print(display_info("title","Seattle",12))
# Out:
# JOB: title
# LOCATION: Seattle
# SALARY: $12

# %%
class JobPost:
  def display_info (title, location, salary):
    return (f"JOB: {title}\nLOCATION: {location}\nSALARY: ${salary}")

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[['total_rooms', 'total_bedrooms']]
# Out:
#       total_rooms  total_bedrooms
# 0          3885.0           661.0
# 1          1510.0           310.0
# 2          3589.0           507.0
# 3            67.0            15.0
# 4          1241.0           244.0
# ...           ...             ...
# 2995       1450.0           642.0
# 2996       5257.0          1082.0
# 2997        956.0           201.0
# 2998         96.0            14.0
# 2999       1765.0           263.0
#
# [3000 rows x 2 columns]

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df = dataset['train'].to_pandas()

# %%
df["job_posting_date"]= pd.to_datetime(df["job_posted_date"])

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg               job_posting_date
# count     22003.000000     10662.000000                         785741
# mean     123286.274072        47.016598  2023-06-25 16:02:11.860248576
# min       15000.000000         8.000000            2023-01-01 00:00:04
# 25%       90000.000000        27.500000            2023-03-20 10:05:48
# 50%      115000.000000        45.980000            2023-06-29 06:11:38
# 75%      150000.000000        61.159996            2023-09-27 01:01:16
# max      960000.000000       391.000000            2023-12-31 23:59:58
# std       48312.449482        21.890738                            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['salary_year_avg'].median()
# Out:
# 115000.0

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
mins = df['salary_year_avg'].idxmin()

# %%
df.iloc[mins]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby("job_title_short")["salary_year_avg"].agg(["min",'max','median','count'])
# Out:
#                                min       max    median  count
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0    610
# Cloud Engineer             42000.0  280000.0   90000.0     65
# Data Analyst               25000.0  650000.0   90000.0   5451
# Data Engineer              15000.0  525000.0  125000.0   4500
# Data Scientist             27000.0  960000.0  127500.0   5922
# Machine Learning Engineer  30000.0  325000.0  106415.0    576
# Senior Data Analyst        30000.0  425000.0  111175.0   1131
# Senior Data Engineer       35000.0  425000.0  147500.0   1591
# Senior Data Scientist      45000.0  890000.0  155500.0   1690
# Software Engineer          28000.0  375000.0   99150.0    467

# %%
us_jobs = df[df['job_country'] == "United States"]

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notnull()]

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min','max','count']).sort_values(by='min')
# Out:
#                                min       max  count
# job_title_short
# Data Engineer              23496.0  525000.0   2915
# Data Analyst               25000.0  375000.0   4350
# Data Scientist             30000.0  960000.0   4553
# Business Analyst           35000.0  387460.0    431
# Senior Data Analyst        35360.0  425000.0    913
# Cloud Engineer             42000.0  221844.0     20
# Machine Learning Engineer  44408.5  315000.0    128
# Senior Data Engineer       45000.0  375000.0   1058
# Software Engineer          48982.0  375000.0    157
# Senior Data Scientist      55000.0  475000.0   1241
